# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread('donald_trump.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1152, 896, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB -> RGB RED GREEN BLUE
# OPENCV -> BLUE GREEN RED

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_gray = cv2.imread('donald_trump.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1152, 896)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray, cmap='gray')

# %%
w_ratio = 0.3
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img, (0,0),fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (576, 269, 3)

# %%
new_img = cv2.flip(fix_img,0)
plt.imshow(new_img)

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpeg', fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
